# %%
import pandas as pd
import numpy as np
import os
from bs4 import BeautifulSoup
from selenium import webdriver
import sys
import json
import csv
import re
from time import sleep

# %%
chromedriver = "chromedriver" # path to the chromedriver executable
chromedriver = os.path.expanduser(chromedriver)
print('chromedriver path: {}'.format(chromedriver))
sys.path.append(chromedriver)
driver = webdriver.Chrome(chromedriver)
# Out:
# chromedriver path: chromedriver

# %%
hrefs=[]
head = ['URL']
def get_page(soup):
#     if soup.find("span", {"class": "css-1uq0cfn"}) is not None: 
#         print("Found")
#         for link in soup.find("span", {"class": "css-1uq0cfn"}).findAll("a"):
#             print(link.get("href"))
#             hrefs.append(str(link.get("href")))
    for a in soup.find_all('a', href=True): 
        if a.text:
            temp1 = a['href'].split('/')
            temp2 = a['href'].split('?')
            if(len(temp2)==1 and len(temp1)>1 and temp1[1]=='biz'):
                url_not_recommended = a['href'].replace("biz", "not_recommended_reviews")
                hrefs.append("https://m.yelp.com"+url_not_recommended)
    else:
        print("N/A")

def hrefcsv(hrefs):    
    with open("apartmentURL_FAKE.csv",'r+') as f:
        writer = csv.writer(f)
        writer.writerow(head)
        for i in hrefs:
            writer.writerow([i])
        f.close()

# %%
pages = [0,10,20]
for i in pages:
    driver.get("https://www.yelp.com/search?cflt=apartments&find_loc=new+york&start="+str(i))
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    get_page(soup)

hrefcsv(hrefs)
# Out:
# N/A
# N/A
# N/A

# %%
hrefs
# Out:
# ['https://m.yelp.com/not_recommended_reviews/avalon-bowery-place-new-york',
#  'https://m.yelp.com/not_recommended_reviews/urban-pads-brooklyn',
#  'https://m.yelp.com/not_recommended_reviews/21-chelsea-new-york-2',
#  'https://m.yelp.com/not_recommended_reviews/250-east-houston-new-york',
#  'https://m.yelp.com/not_recommended_reviews/mima-new-york',
#  'https://m.yelp.com/not_recommended_reviews/ava-fort-greene-brooklyn',
#  'https://m.yelp.com/not_recommended_reviews/ava-dobro-brooklyn',
#  'https://m.yelp.com/not_recommended_reviews/the-lanthian-apartments-new-york-2',
#  'https://m.yelp.com/not_recommended_reviews/the-dylan-new-york-2',
#  'https://m.yelp.com/not_recommended_reviews/95-wall-new-york',
#  'https://m.yelp.com/not_recommended_reviews/urban-pads-brooklyn',
#  'https://m.yelp.com/not_recommended_reviews/east-village-apartments-by-sudha-new-york',
#  'https://m.yelp.com/not_recommended_reviews/the-courtney-house-new-york',
#  'https://m.yelp.com/not_recommended_reviews/388-bridge-brooklyn',
#  'https://m.yelp.com/not_recommended_reviews/the-greystone-new-york',
#  'https://m.yelp.com/not_recommended_reviews/24-fifth-avenue-new-york-2',
#  'https://m.yelp.com/not_recommended_reviews/the-brooklyner-apartments-brooklyn',
#  'https://m.yelp.com/not_recommended_reviews/post-luminaria-new-york-2',
#  'https://m.yelp.com/not_recommended_reviews/the-tate-new-york',
#  'https://m.yelp.com/not_recommended_reviews/barclay-tower-glenwood-new-york',
#  'https://m.yelp.com/not_recommended_reviews/prism-at-park-avenue-south-apartments-new-york',
#  'https://m.yelp.com/not_recommended_reviews/east-village-apartments-by-sudha-new-york',
#  'https://m.yelp.com/not_recommended_reviews/murray-hill-marquis-new-york',
#  'https://m.yelp.com/not_recommended_reviews/88-leonard-new-york',
#  'https://m.yelp.com/not_recommended_reviews/avalon-willoughby-square-brooklyn',
#  'https://m.yelp.com/not_recommended_reviews/historic-front-street-new-york',
#  'https://m.yelp.com/not_recommended_reviews/34-berry-brooklyn',
#  'https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2',
#  'https://m.yelp.com/not_recommended_reviews/atlas-new-york-manhattan',
#  'https://m.yelp.com/not_recommended_reviews/420-kent-brooklyn',
#  'https://m.yelp.com/not_recommended_reviews/200-water-street-apartments-new-york',
#  'https://m.yelp.com/not_recommended_reviews/66-rockwell-apartments-fort-greene',
#  'https://m.yelp.com/not_recommended_reviews/murray-hill-marquis-new-york']

# %%
d = pd.read_csv('apartmentURL_FAKE.csv')
d.drop_duplicates(keep=False,inplace=True)

# %%
date = []
username = []
date = []
location = []
review_count = []
friend_count = []
photo_count =[]
rating = []
comments = []

def get_fake_comments(url): 
    
    driver = webdriver.Chrome('chromedriver')
    
    # create url for "not recommended" page based on original restaurant URL 
    url_not_recommended = url.replace("biz", "not_recommended_reviews")
    
    # launch scraper on URL
    driver.get(url_not_recommended)
    sleep(10)
    
    # create list for all DF columns
    
    
    
    # while loop used in order to iterate to "next pages"
    # main comment block
    while True:
        bad_comment_blocks = driver.find_elements_by_css_selector(".not-recommended-reviews")[0].find_elements_by_css_selector(".review.review--with-sidebar")
        
        # iterate through comment block to get all comment features for 1 page


        for i in range(0, (len(bad_comment_blocks))):

            try:
                comments.append(bad_comment_blocks[i].find_element_by_tag_name("p").text)
            except:
                comments.append("N/A")


            try:
                rating.append(bad_comment_blocks[i].find_elements_by_css_selector(".i-stars")[0].get_attribute("title").split()[0])

            except: 
                rating.append("N/A")


            try:
                username.append(bad_comment_blocks[i].find_elements_by_css_selector(".user-display-name")[0].text)
            except: 
                username.append("Not Yelp User")

            try:
                review_count.append(bad_comment_blocks[i].find_elements_by_css_selector(".review-count")[0].text.split()[0])
            except: 
                review_count.append("N/A")

            try:
                friend_count.append(bad_comment_blocks[i].find_elements_by_css_selector(".friend-count")[0].text.split()[0])
            except: 
                friend_count.append("N/A")


            try: 
                location.append(bad_comment_blocks[i].find_elements_by_css_selector(".user-location")[0].text)
            except: 
                location.append("N/A")


            try: 
                date.append(bad_comment_blocks[i].find_elements_by_css_selector(".rating-qualifier")[0].text)
            except: 
                date.append("N/A")
            
            try:
                photo_count.append(bad_comment_blocks[i].find_elements_by_css_selector(".photo-count")[0].text.split()[0])
            except: 
                photo_count.append("N/A")
            
            
        try:
            #navigate to the next page
            driver.find_elements_by_css_selector(".not-recommended-reviews")[0].find_elements_by_css_selector('.icon.icon--24-chevron-right.icon--size-24')[0].click()
            print(url_not_recommended, 'subpage scraped')
            sleep(7) 
        except:
            ()
            break

    # make dict of all lists, order as per same scraper for recommended comments
    # add some columns with constant values

    
 

    


#     return data
#     print(len(data))
#     print(data.describe())

# %%
for urls in d['URL']:
    get_fake_comments(urls)
# Out:
# https://m.yelp.com/not_recommended_reviews/avalon-bowery-place-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/avalon-bowery-place-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/21-chelsea-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/250-east-houston-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/250-east-houston-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/mima-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/ava-fort-greene-brooklyn subpage scraped
# https://m.yelp.com/not_recommended_reviews/ava-dobro-brooklyn subpage scraped
# https://m.yelp.com/not_recommended_reviews/ava-dobro-brooklyn subpage scraped
# https://m.yelp.com/not_recommended_reviews/95-wall-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/95-wall-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/95-wall-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/the-greystone-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/the-greystone-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/the-greystone-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/the-brooklyner-apartments-brooklyn subpage scraped
# https://m.yelp.com/not_recommended_reviews/the-brooklyner-apartments-brooklyn subpage scraped
# https://m.yelp.com/not_recommended_reviews/prism-at-park-avenue-south-apartments-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/prism-at-park-avenue-south-apartments-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/prism-at-park-avenue-south-apartments-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/avalon-willoughby-square-brooklyn subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/city-wide-apartments-new-york-2 subpage scraped
# https://m.yelp.com/not_recommended_reviews/atlas-new-york-manhattan subpage scraped
# https://m.yelp.com/not_recommended_reviews/atlas-new-york-manhattan subpage scraped
# https://m.yelp.com/not_recommended_reviews/200-water-street-apartments-new-york subpage scraped
# https://m.yelp.com/not_recommended_reviews/66-rockwell-apartments-fort-greene subpage scraped
# https://m.yelp.com/not_recommended_reviews/66-rockwell-apartments-fort-greene subpage scraped
# https://m.yelp.com/not_recommended_reviews/66-rockwell-apartments-fort-greene subpage scraped
# https://m.yelp.com/not_recommended_reviews/66-rockwell-apartments-fort-greene subpage scraped

# %%
dd = {"date" : date,
         "username" : username,
         "photos_for_review" : [-1] * len(date),
         "rating" : rating,
         "text_review" : comments, 
         "user_location" : location, 
         "user_friends_count" : friend_count, 
         "user_reviews_count" : review_count, 
         "user_total_image_posted" : photo_count, 
         "is_real_review" : [0] * len(date), 
         
        }
         
         
data = pd.DataFrame(dd)
print(len(data))
print(data.describe())
# Out:
# 589
#        photos_for_review  is_real_review
# count              589.0           589.0
# mean                -1.0             0.0
# std                  0.0             0.0
# min                 -1.0             0.0
# 25%                 -1.0             0.0
# 50%                 -1.0             0.0
# 75%                 -1.0             0.0
# max                 -1.0             0.0

# %%
# saving the dataframe
data.to_csv('FAKE_PROPERTY_REVIEW_YELP.csv',index=False)

# %%
p = pd.read_csv('FAKE_PROPERTY_REVIEW_YELP.csv')
p
# Out:
#                          date    username  photos_for_review  rating  \
# 0                   9/10/2018        B C.                 -1     1.0
# 1    4/5/2017\nUpdated review    Brian L.                 -1     1.0
# 2                   4/29/2016    Aidan S.                 -1     5.0
# 3                   4/23/2016   Rachel A.                 -1     5.0
# 4                   4/12/2016    Fenil G.                 -1     5.0
# ..                        ...         ...                ...     ...
# 584                10/25/2017   Darryl R.                 -1     5.0
# 585                10/21/2017     Mike K.                 -1     5.0
# 586                10/17/2017  Stephen L.                 -1     5.0
# 587                 2/15/2017     Nate A.                 -1     5.0
# 588                  1/9/2017     Joey M.                 -1     5.0
#
#                                            text_review  \
# 0    These people are thieves and con artists.  Do ...
# 1    Just classic. I came back to yelp to see if th...
# 2    I have been living here for the past 18 months...
# 3    We just moved out of Bowery Place and we absol...
# 4    I have lived the building for six years and it...
# ..                                                 ...
# 584  I moved into the building after subletting an ...
# 585  Moved in a little over a month ago and it's my...
# 586  Very easy process, great apartments, great loc...
# 587  There are NY apartments and then there is this...
# 588  I moved into 66 Rockwell over 2 years ago and ...
#
#                user_location  user_friends_count  user_reviews_count  \
# 0         Franklin Lakes, NJ                   0                  28
# 1    Manhattan, New York, NY                   0                   1
# 2              Manhattan, NY                   0                   2
# 3              Manhattan, NY                   0                   2
# 4              Manhattan, NY                   0                   3
# ..                       ...                 ...                 ...
# 584             Brooklyn, NY                  15                   2
# 585   Brooklyn, Brooklyn, NY                 242                   2
# 586        San Francisco, CA                   0                   6
# 587   Brooklyn, Brooklyn, NY                 278                   3
# 588   Brooklyn, Brooklyn, NY                   0                   3
#
#      user_total_image_posted  is_real_review
# 0                        NaN               0
# 1                        NaN               0
# 2                        NaN               0
# 3                        NaN               0
# 4                        NaN               0
# ..                       ...             ...
# 584                      NaN               0
# 585                      NaN               0
# 586                      NaN               0
# 587                      NaN               0
# 588                      NaN               0
#
# [589 rows x 10 columns]
