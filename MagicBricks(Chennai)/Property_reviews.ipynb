# %%
import pandas as pd
import numpy as np
import os
from bs4 import BeautifulSoup
from selenium import webdriver
import sys
import json
import csv
import re

# %%
chromedriver = "C:/Users/Rohit/Desktop/7th Sem/chromedriver" # path to the chromedriver executable
chromedriver = os.path.expanduser(chromedriver)
print('chromedriver path: {}'.format(chromedriver))
sys.path.append(chromedriver)
driver = webdriver.Chrome(chromedriver)
# Out:
# chromedriver path: C:/Users/Rohit/Desktop/7th Sem/chromedriver

# %%
hrefdata = pd.read_csv('href.csv')
hrefdata.head(4)
# Out:
#                                                 href
# 0  https://www.magicbricks.com/tvs-emerald-atrium...
# 1  https://www.magicbricks.com/dac-chromantique-c...
# 2  https://www.magicbricks.com/nest-epic-medavakk...
# 3  https://www.magicbricks.com/radiance-the-pride...

# %%
cols = ['property_name','reviewer','date','stars','heading','review']
r=[]
def get_review(soup):
    prop=soup.find_all('div',class_='review-block')
    property_name = soup.find('h1',class_='heading')
    if property_name is None:
            property_name = "?"
    else:
        property_name = str(property_name.get_text())
    for i in prop:
        temp=[]
        reviewer=i.find('div',{"class" : "review__name ellipsis"})
        date = i.find('div',class_='review__date')
        stars = i.find_all('span', class_='rating__star full')
        stars = len(stars)
        heading = i.find('div',class_='heading-2 ellipsis')
        review = i.find('div',class_='review__msg addReadMore showlesscontent')
        
            
        if reviewer is None:
            reviewer="?"
        else:
            reviewer = str(reviewer.get_text())
        if date is None:
            date="?"
        else:
            date = str(date.get_text())
        if heading is None:
            reviewer="?"
        else:
            heading = str(heading.get_text())
        if review is None:
            review="?"
        else:
            review = str(review.get_text())
        
        
        temp = [property_name,reviewer,date,stars,heading,review]
        r.append(temp)

# %%
with open("reviews.csv",'w') as f:
    print("csv file")
    f.close()
# Out:
# csv file

# %%
num=0

for hr in hrefdata['href']:    
    driver.get(hr)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    get_review(soup)
    
with open("reviews.csv",'r+') as f:
    writer = csv.writer(f)
    writer.writerow(cols)
    for i in r:
        writer.writerow(i)
    f.close()

# %%
reviews = pd.read_csv('reviews.csv')
reviews
# Out:
#                          property_name    reviewer        date  stars  \
# 0    TVS Emerald Atrium at Green Acres        Raja  27/01/2016      4
# 1                     DAC Chromantique      Venkat  11/05/2014      4
# 2                            Nest Epic       Mohan  31/05/2014      4
# 3                   Radiance The Pride      Vishwa  07/03/2015      4
# 4                       Brigade Xanadu  Guest User  21/05/2021      3
# ..                                 ...         ...         ...    ...
# 349               Provident Cosmo City  Guest User  20/08/2020      3
# 350               Provident Cosmo City     Ayyanar  18/03/2015      5
# 351                  Aishwarya Gardens  Guest User  12/07/2020      5
# 352                  Aishwarya Gardens  Guest User  12/07/2020      5
# 353                  Aishwarya Gardens      Barani  20/06/2015      4
#
#                           heading  \
# 0                     Kolapakkam.
# 1                   Chitlapakkam.
# 2                     Medavakkam.
# 3                     Pallavaram.
# 4                   Nice project.
# ..                            ...
# 349                 Nice project.
# 350                     Siruseri.
# 351  Aishwarya Gardens_Medavakkam
# 352  Aishwarya Gardens_Medavakkam
# 353                   Medavakkam.
#
#                                                 review
# 0                                                    ?
# 1                                                    ?
# 2                                                    ?
# 3                                                    ?
# 4    Still the project is under construction posses...
# ..                                                 ...
# 349  This apartment located in Siruseri. This apart...
# 350                                                  ?
# 351  Good amenities, providing all facilities to th...
# 352  Good amenities, providing all facilities to th...
# 353                                                  ?
#
# [354 rows x 6 columns]

# %%
reviews.shape
# Out:
# (354, 6)
